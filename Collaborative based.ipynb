# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.decomposition import TruncatedSVD
import warnings

# %%
movie = pd.read_csv('movies.csv')
rating = pd.read_csv('ratings.csv')

# %%
movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
rating.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
movie.drop('genres', axis=1, inplace=True)
rating.drop('timestamp', axis=1, inplace=True)

# %%
data = movie.merge(rating, on='movieId')

# %%
data.head()
# Out:
#    movieId             title  userId  rating
# 0        1  Toy Story (1995)       1     4.0
# 1        1  Toy Story (1995)       5     4.0
# 2        1  Toy Story (1995)       7     4.5
# 3        1  Toy Story (1995)      15     2.5
# 4        1  Toy Story (1995)      17     4.5

# %%
New_Data = data.dropna(axis=0, subset=['title'])

# %%
Rating_Count = (New_Data.groupby('title')['rating'].count().reset_index())

# %%
Rating_Count.head()
# Out:
#                                      title  rating
# 0                               '71 (2014)       1
# 1  'Hellboy': The Seeds of Creation (2004)       1
# 2                   'Round Midnight (1986)       2
# 3                      'Salem's Lot (2004)       1
# 4                'Til There Was You (1997)       2

# %%
Rating_Count['Total_Rating_Count']=Rating_Count['rating']
Rating_Count.drop('rating', axis=1, inplace=True)

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
print(Rating_Count['Total_Rating_Count'].describe())
# Out:
# count   9719.000
# mean      10.375
# std       22.406
# min        1.000
# 25%        1.000
# 50%        3.000
# 75%        9.000
# max      329.000
# Name: Total_Rating_Count, dtype: float64

# %%
print(Rating_Count['Total_Rating_Count'].quantile(np.arange(.9,1,.01)))
# Out:
# 0.900    27.000
# 0.910    30.000
# 0.920    33.560
# 0.930    38.000
# 0.940    42.000
# 0.950    47.000
# 0.960    55.000
# 0.970    64.460
# 0.980    83.000
# 0.990   114.640
# Name: Total_Rating_Count, dtype: float64

# %%
Final = New_Data.merge(Rating_Count, left_on='title', right_on='title', how='left')

# %%
Final.head()
# Out:
#    movieId             title  userId  rating  Total_Rating_Count
# 0        1  Toy Story (1995)       1   4.000                 215
# 1        1  Toy Story (1995)       5   4.000                 215
# 2        1  Toy Story (1995)       7   4.500                 215
# 3        1  Toy Story (1995)      15   2.500                 215
# 4        1  Toy Story (1995)      17   4.500                 215

# %%
Threshold = 50
New_Final = Final.query('Total_Rating_Count >= @Threshold')
New_Final.head()
# Out:
#    movieId             title  userId  rating  Total_Rating_Count
# 0        1  Toy Story (1995)       1   4.000                 215
# 1        1  Toy Story (1995)       5   4.000                 215
# 2        1  Toy Story (1995)       7   4.500                 215
# 3        1  Toy Story (1995)      15   2.500                 215
# 4        1  Toy Story (1995)      17   4.500                 215

# %%
Features = New_Final.pivot_table(values='rating', index='userId', columns='title').fillna(0)
Features.head()
# Out:
# title   10 Things I Hate About You (1999)  12 Angry Men (1957)  \
# userId
# 1                                   0.000                0.000
# 2                                   0.000                0.000
# 3                                   0.000                0.000
# 4                                   0.000                5.000
# 5                                   0.000                0.000
#
# title   2001: A Space Odyssey (1968)  28 Days Later (2002)  300 (2007)  \
# userId
# 1                              0.000                 0.000       0.000
# 2                              0.000                 0.000       0.000
# 3                              0.000                 0.000       0.000
# 4                              0.000                 0.000       0.000
# 5                              0.000                 0.000       0.000
#
# title   40-Year-Old Virgin, The (2005)  A.I. Artificial Intelligence (2001)  \
# userId
# 1                                0.000                                0.000
# 2                                0.000                                0.000
# 3                                0.000                                0.000
# 4                                0.000                                0.000
# 5                                0.000                                0.000
#
# title   Abyss, The (1989)  Ace Ventura: Pet Detective (1994)  \
# userId
# 1                   4.000                              0.000
# 2                   0.000                              0.000
# 3                   0.000                              0.000
# 4                   0.000                              0.000
# 5                   0.000                              3.000
#
# title   Ace Ventura: When Nature Calls (1995)  ...  \
# userId                                         ...
# 1                                       0.000  ...
# 2                                       0.000  ...
# 3                                       0.000  ...
# 4                                       0.000  ...
# 5                                       0.000  ...
#
# title   Willy Wonka & the Chocolate Factory (1971)  Wizard of Oz, The (1939)  \
# userId
# 1                                            5.000                     5.000
# 2                                            0.000                     0.000
# 3                                            0.000                     0.000
# 4                                            4.000                     5.000
# 5                                            0.000                     0.000
#
# title   Wolf of Wall Street, The (2013)  X-Men (2000)  \
# userId
# 1                                 0.000         5.000
# 2                                 5.000         0.000
# 3                                 0.000         0.000
# 4                                 0.000         0.000
# 5                                 0.000         0.000
#
# title   X-Men: The Last Stand (2006)  X2: X-Men United (2003)  \
# userId
# 1                              0.000                    0.000
# 2                              0.000                    0.000
# 3                              0.000                    0.000
# 4                              0.000                    0.000
# 5                              0.000                    0.000
#
# title   You've Got Mail (1998)  Young Frankenstein (1974)  Zombieland (2009)  \
# userId
# 1                        0.000                      5.000              0.000
# 2                        0.000                      0.000              3.000
# 3                        0.500                      0.000              0.000
# 4                        0.000                      0.000              0.000
# 5                        0.000                      0.000              0.000
#
# title   Zoolander (2001)
# userId
# 1                  0.000
# 2                  0.000
# 3                  0.000
# 4                  0.000
# 5                  0.000
#
# [5 rows x 450 columns]

# %%
Features.shape
# Out:
# (606, 450)

# %%
X = Features.values.T
X.shape
# Out:
# (450, 606)

# %%
SVD = TruncatedSVD(n_components=12, random_state=17)
Matrix = SVD.fit_transform(X)
Matrix.shape
# Out:
# (450, 12)

# %%
warnings.filterwarnings("ignore", category=RuntimeWarning)
Correlation = np.corrcoef(Matrix)
Correlation.shape
# Out:
# (450, 450)

# %%
Movie_Title = Features.columns
Movie_List = list(Movie_Title)

# %%
Wizard = Movie_List.index("Wizard of Oz, The (1939)")
print(Wizard)
# Out:
# 441

# %%
Recommend = Correlation[Wizard]
list(Movie_Title[(Recommend >= 0.9)])
# Out:
# ['Animal House (1978)',
#  'Beetlejuice (1988)',
#  'Big (1988)',
#  "Bug's Life, A (1998)",
#  'Christmas Story, A (1983)',
#  'Crocodile Dundee (1986)',
#  'E.T. the Extra-Terrestrial (1982)',
#  'Fantasia (1940)',
#  'Goonies, The (1985)',
#  'Grease (1978)',
#  'Honey, I Shrunk the Kids (1989)',
#  'Jaws (1975)',
#  'Jungle Book, The (1967)',
#  'Lady and the Tramp (1955)',
#  'Little Mermaid, The (1989)',
#  'Mary Poppins (1964)',
#  'Romancing the Stone (1984)',
#  'Sound of Music, The (1965)',
#  'Splash (1984)',
#  'To Kill a Mockingbird (1962)',
#  'Who Framed Roger Rabbit? (1988)',
#  'Wizard of Oz, The (1939)']

# %%
print(Correlation[Wizard])
# Out:
# [0.73044285 0.7513778  0.73524344 0.52948559 0.52768435 0.64948809
#  0.65196762 0.71106869 0.52861515 0.61668866 0.48296858 0.63839798
#  0.88125068 0.69302763 0.75027864 0.67546771 0.78019872 0.82995116
#  0.44444486 0.7168575  0.53100436 0.74194728 0.55603249 0.66826941
#        'Splash (1984)', 'To Kill a Mockingbird (1962)',
#        'Who Framed Roger Rabbit? (1988)', 'Wizard of Oz, The (1939)'],
#       dtype='object', name='title')

# %%
print(Movie_Title[(Recommend >= 0.8)])
# Out:
# Index(['Airplane! (1980)', 'Amadeus (1984)', 'Animal House (1978)',
#        'Arachnophobia (1990)',
#        'Austin Powers: International Man of Mystery (1997)',
#        'Austin Powers: The Spy Who Shagged Me (1999)',
#        'Back to the Future (1985)', 'Back to the Future Part II (1989)',
#        'Back to the Future Part III (1990)', 'Batman Returns (1992)',
#        'Beetlejuice (1988)', 'Being John Malkovich (1999)', 'Big (1988)',
#        'Blazing Saddles (1974)', 'Blues Brothers, The (1980)',
#        'Breakfast Club, The (1985)', 'Bug's Life, A (1998)',
#        'Butch Cassidy and the Sundance Kid (1969)', 'Caddyshack (1980)',
#        'Casablanca (1942)', 'Christmas Story, A (1983)', 'Citizen Kane (1941)',
#        'Close Encounters of the Third Kind (1977)', 'Cool Hand Luke (1967)',
#        'Crocodile Dundee (1986)', 'E.T. the Extra-Terrestrial (1982)',
#        'Edward Scissorhands (1990)', 'Exorcist, The (1973)', 'Fantasia (1940)',
#        'Ferris Bueller's Day Off (1986)', 'Few Good Men, A (1992)',
#        'Field of Dreams (1989)', 'Fish Called Wanda, A (1988)',
#        'Galaxy Quest (1999)', 'Ghostbusters (a.k.a. Ghost Busters) (1984)',
#        'Goldfinger (1964)', 'Goonies, The (1985)', 'Grease (1978)',
#        'Groundhog Day (1993)', 'Honey, I Shrunk the Kids (1989)',
#        'Hook (1991)', 'Indiana Jones and the Temple of Doom (1984)',
#        'It's a Wonderful Life (1946)', 'Jaws (1975)',
#        'Jungle Book, The (1967)', 'Lady and the Tramp (1955)',
#        'Little Mermaid, The (1989)', 'Mary Poppins (1964)',
#        'Men in Black (a.k.a. MIB) (1997)',
#        'Monty Python and the Holy Grail (1975)', 'My Cousin Vinny (1992)',
#        'Nightmare Before Christmas, The (1993)', 'Pinocchio (1940)',
#        'Planet of the Apes (1968)', 'Pleasantville (1998)',
#        'Princess Bride, The (1987)', 'Psycho (1960)', 'Rain Man (1988)',
#        'Raising Arizona (1987)', 'Rocky (1976)',
#        'Rocky Horror Picture Show, The (1975)', 'Romancing the Stone (1984)',
#        'Scream (1996)', 'Shakespeare in Love (1998)', 'Shining, The (1980)',
#        'Some Like It Hot (1959)', 'Sound of Music, The (1965)',
#        'Spaceballs (1987)', 'Splash (1984)', 'Stand by Me (1986)',
#        'This Is Spinal Tap (1984)', 'To Kill a Mockingbird (1962)',
#        'Top Gun (1986)', 'Toy Story (1995)', 'Toy Story 2 (1999)',
#        'Wallace & Gromit: The Wrong Trousers (1993)', 'Wayne's World (1992)',
#        'Wedding Singer, The (1998)', 'When Harry Met Sally... (1989)',
#        'Who Framed Roger Rabbit? (1988)',
#        'Willy Wonka & the Chocolate Factory (1971)',
#        'Wizard of Oz, The (1939)', 'Young Frankenstein (1974)'],
#       dtype='object', name='title')
